# %% [markdown]
# ##**Sample** - A sample is a subset of data from a larger data set; statisticians call this larger data set the population.
#
# ##**Population** -  A population in statistics is not the same thing as in biology—it is a large, defined (but sometimes theoretical or imaginary) set of data.
#
# ##**Random sampling** - Random sampling is a process in which each available member of the population being sampled has an equal chance of being chosen for the sample at each draw.
#
# ##**Strata** - A homogeneous subgroup of a population with common characteristics.
#
# ##**Stratified sampling** - Dividing the population into strata and randomly sampling from each strata.
#
# ##**Bias** - Systematic errror
#
# ##**Sample bias** - A sample that misrepresents the population

# %% [markdown]
# ##The Scatterplot of shots from a gun with true aim.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##. Scatterplot of shots from a gun with biased aim
#
# ![image.png](data:image/png;base64,...)
